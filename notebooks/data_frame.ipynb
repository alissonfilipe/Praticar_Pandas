# %%
import pandas as pd

df = pd.DataFrame({
    'nome' : ['ana','Bruno','carlos','Daniela'],
    'idade': [23,30,19,25],
    'cidade':['SP','rj','Sp','bh'],
    'salario':[3000,4500,2000,3800]
})

# %%
df['idade_ano_que_vem'] = df['idade'] + 1

# %%
df
# Out:
#       nome  idade cidade  salario  idade_ano_que_vem
# 0      ana     23     SP     3000                 24
# 1    Bruno     30     rj     4500                 31
# 2   carlos     19     Sp     2000                 20
# 3  Daniela     25     bh     3800                 26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nome               4 non-null      object
#  1   idade              4 non-null      int64
#  2   cidade             4 non-null      object
#  3   salario            4 non-null      int64
#  4   idade_ano_que_vem  4 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 292.0+ bytes
